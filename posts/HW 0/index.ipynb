# %%
import pandas as pd
url = "https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/palmer_penguins.csv"
penguins = pd.read_csv(url)

# %%
penguins.head(5)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
#create a subdf 
print(penguins.columns)
penguins_copy = penguins.copy()
cols = []
penguins_copy = penguins_copy[['Species', 'Region', 'Island',  'Culmen Length (mm)',
       'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
       'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']]
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
import pandas as pd
from sklearn import preprocessing

df = pd.DataFrame({'label': ['some_label', 'some_label', 'a_diff_label', 'a_diff_label']})

le = preprocessing.LabelEncoder()
df['label'] = le.fit_transform(df['label'])
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64

# %%
penguins_copy.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/toeknee/Library/CloudStorage/OneDrive-UCLAITServices/UCLA/Year 4/PIC 16B/Blog (HW)/posts/HW 0/hw0.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/toeknee/Library/CloudStorage/OneDrive-UCLAITServices/UCLA/Year%204/PIC%2016B/Blog%20%28HW%29/posts/HW%200/hw0.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> penguins_copy.corr()
#
# File ~/anaconda3/envs/PIC16B/lib/python3.9/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data = penguins_copy, x='Culmen Length (mm)', y = 'Flipper Length (mm)', hue = 'Island')
# Out:
# <Axes: xlabel='Culmen Length (mm)', ylabel='Flipper Length (mm)'>
